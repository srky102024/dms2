# %%
# !pip install pymongo
# !pip install uuid

import pymongo
import uuid
from datetime import datetime

# Connect to MongoDB
client = pymongo.MongoClient("mongodb+srv://i40:dbms2@cluster0.lixbqmp.mongodb.net/lab3")

# Define database and collection
db = client['lab3']
collection_name = '3791_AmithGopi'
collection = db[collection_name]

# Clear the collection to avoid duplicates
collection.delete_many({})

# Create and insert exactly 1000 objects into the collection
objects = []
for i in range(1000):
 obj = {
 "_id": str(uuid.uuid4()),
 "uuid": str(uuid.uuid4()),
 "source_database": "MongoDB",
 "created_at": datetime.utcnow().isoformat(),
 "updated_at": datetime.utcnow().isoformat(),
 "attribute1": f"attribute_value_{i}",
 "attribute2": f"attribute_value_{i+1}",
 "attribute3": f"attribute_value_{i+2}"
 }
objects.append(obj)

# Insert objects into the collection
collection.insert_many(objects)

# Check the count to verify there are exactly 1000 do!pip install pymongo
# !pip install uuid

import pymongo
import uuid
from datetime import datetime

# Connect to MongoDB
client = pymongo.MongoClient("mongodb+srv://i40:dbms2@cluster0.lixbqmp.mongodb.net/lab3")

# Define database and collection
db = client['lab3']
collection_name = '4996_Chukshith'
collection = db[collection_name]

# Clear the collection to avoid duplicates
collection.delete_many({})

# Create and insert exactly 1000 objects into the collection
objects = []
for i in range(1000):
    obj = {
        "_id": str(uuid.uuid4()),
        "uuid": str(uuid.uuid4()),
        "source_database": "MongoDB",
        "created_at": datetime.utcnow().isoformat(),
        "updated_at": datetime.utcnow().isoformat(),
        "attribute1": f"attribute_value_{i}",
        "attribute2": f"attribute_value_{i+1}",
        "attribute3": f"attribute_value_{i+2}"
    }
    objects.append(obj)

# Insert objects into the collection
collection.insert_many(objects)

# Check the count to verify there are exactly 1000 documents
count = collection.count_documents({})
print(f"Total documents in collection: {count}")

# Retrieve and display 5 sample documents from the collection
sample_data = collection.find().limit(5)
for data in sample_data:
    print(data)

count = collection.count_documents({})
print(f"Total documents in collection: {count}")

# Retrieve and display 5 sample documents from the collection
sample_data = collection.find().limit(5)
for data in sample_data:
 print(data)
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.10.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.7.0)
# Requirement already satisfied: uuid in /usr/local/lib/python3.10/dist-packages (1.30)
# Requirement already satisfied: uuid in /usr/local/lib/python3.10/dist-packages (1.30)
# Total documents in collection: 1000
# {'_id': '9ea4ccfa-bb49-44f5-a34f-5b747aef4bcb', 'uuid': '47441648-1639-4f79-8352-310d1af8a4ce', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763167', 'updated_at': '2024-10-09T06:06:58.763185', 'attribute1': 'attribute_value_0', 'attribute2': 'attribute_value_1', 'attribute3': 'attribute_value_2'}
# {'_id': 'a349c030-7b7a-4cf0-8761-b1a4044d7d3b', 'uuid': '33f1ced2-ae17-4e56-9a6a-fc7d53c69777', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763229', 'updated_at': '2024-10-09T06:06:58.763233', 'attribute1': 'attribute_value_1', 'attribute2': 'attribute_value_2', 'attribute3': 'attribute_value_3'}
# {'_id': '31f5762d-f5eb-4fc4-852f-7af4c2402cb3', 'uuid': 'd5d4972b-f496-43e9-9d79-341ccdf75ecd', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763260', 'updated_at': '2024-10-09T06:06:58.763264', 'attribute1': 'attribute_value_2', 'attribute2': 'attribute_value_3', 'attribute3': 'attribute_value_4'}
# {'_id': 'cbec9942-beb3-461e-aab7-d156a8ff3408', 'uuid': '677a699d-3ea4-4c5d-bb7c-47560feb83e3', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763289', 'updated_at': '2024-10-09T06:06:58.763292', 'attribute1': 'attribute_value_3', 'attribute2': 'attribute_value_4', 'attribute3': 'attribute_value_5'}
# {'_id': 'e3a160bb-7ac5-4d6c-bd1f-1e35bd6bbc30', 'uuid': '5c1e48be-69dd-480c-bd73-85455416f012', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763318', 'updated_at': '2024-10-09T06:06:58.763322', 'attribute1': 'attribute_value_4', 'attribute2': 'attribute_value_5', 'attribute3': 'attribute_value_6'}
# Total documents in collection: 1000
# {'_id': '9ea4ccfa-bb49-44f5-a34f-5b747aef4bcb', 'uuid': '47441648-1639-4f79-8352-310d1af8a4ce', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763167', 'updated_at': '2024-10-09T06:06:58.763185', 'attribute1': 'attribute_value_0', 'attribute2': 'attribute_value_1', 'attribute3': 'attribute_value_2'}
# {'_id': 'a349c030-7b7a-4cf0-8761-b1a4044d7d3b', 'uuid': '33f1ced2-ae17-4e56-9a6a-fc7d53c69777', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763229', 'updated_at': '2024-10-09T06:06:58.763233', 'attribute1': 'attribute_value_1', 'attribute2': 'attribute_value_2', 'attribute3': 'attribute_value_3'}
# {'_id': '31f5762d-f5eb-4fc4-852f-7af4c2402cb3', 'uuid': 'd5d4972b-f496-43e9-9d79-341ccdf75ecd', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763260', 'updated_at': '2024-10-09T06:06:58.763264', 'attribute1': 'attribute_value_2', 'attribute2': 'attribute_value_3', 'attribute3': 'attribute_value_4'}
# {'_id': 'cbec9942-beb3-461e-aab7-d156a8ff3408', 'uuid': '677a699d-3ea4-4c5d-bb7c-47560feb83e3', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763289', 'updated_at': '2024-10-09T06:06:58.763292', 'attribute1': 'attribute_value_3', 'attribute2': 'attribute_value_4', 'attribute3': 'attribute_value_5'}
# {'_id': 'e3a160bb-7ac5-4d6c-bd1f-1e35bd6bbc30', 'uuid': '5c1e48be-69dd-480c-bd73-85455416f012', 'source_database': 'MongoDB', 'created_at': '2024-10-09T06:06:58.763318', 'updated_at': '2024-10-09T06:06:58.763322', 'attribute1': 'attribute_value_4', 'attribute2': 'attribute_value_5', 'attribute3': 'attribute_value_6'}
